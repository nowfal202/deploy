# %% [markdown]
# ## XCEPTION NET ARCHITECTURE

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
import tensorflow as tf
print(tf.__version__)

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU



from time import time
import numpy as np

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From D:\ANACONDA\envs\env\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,validation_split = 0.2)
train_data=train.flow_from_directory(directory = 'DATASET/TRAIN',target_size=(224,224),
                                     batch_size=32,class_mode='categorical')
# Out:
# Found 2506 images belonging to 20 classes.

# %%
test=ImageDataGenerator(rescale=1./255)
test_data=test.flow_from_directory(directory = 'DATASET/TEST',target_size=(224,224),
                                   batch_size=32,class_mode='categorical')
# Out:
# Found 2506 images belonging to 20 classes.

# %%
def xception(input_shape, n_classes):
  
  def conv_bn(x, f, k, s=1, p='same'):
    x = Conv2D(f, k, strides=s, padding=p, use_bias=False)(x)
    x = BatchNormalization()(x)
    return x
  
  
  def sep_bn(x, f, k, s=1, p='same'):
    x = SeparableConv2D(f, k, strides=s, padding=p, use_bias=False)(x)
    x = BatchNormalization()(x)
    return x
  
  
  def entry_flow(x):
    x = conv_bn(x, 32, 3, 2)
    x = ReLU()(x)
    x = conv_bn(x, 64, 3)
    tensor = ReLU()(x)
    
    x = sep_bn(tensor, 128, 3)
    x = ReLU()(x)
    x = sep_bn(x, 128, 3)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    tensor = conv_bn(tensor, 128, 1, 2)
    
    x = Add()([tensor, x])
    x = ReLU()(x)
    x = sep_bn(x, 256, 3)
    x = ReLU()(x)
    x = sep_bn(x, 256, 3)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    tensor = conv_bn(tensor, 256, 1, 2)
    
    x = Add()([tensor, x])
    x = ReLU()(x)
    x = sep_bn(x, 728, 3)
    x = ReLU()(x)
    x = sep_bn(x, 728, 3)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    tensor = conv_bn(tensor, 728, 1, 2)
    x = Add()([tensor, x])
    
    return x
  
  
  def middle_flow(tensor):
    for _ in range(8):
      x = ReLU()(tensor)
      x = sep_bn(x, 728, 3)
      x = ReLU()(x)
      x = sep_bn(x, 728, 3)
      x = ReLU()(x)
      x = sep_bn(x, 728, 3)

      tensor = Add()([tensor, x])
    
    return tensor
  
  
  def exit_flow(tensor):
    x = ReLU()(tensor)
    x = sep_bn(x, 728, 3)
    x = ReLU()(x)
    x = sep_bn(x, 1024, 3)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    tensor = conv_bn(tensor, 1024, 1, 2)
    
    x = Add()([tensor, x])
    x = sep_bn(x, 1536, 3)
    x = ReLU()(x)
    x = sep_bn(x, 2048, 3)
    x = ReLU()(x)
    x = GlobalAvgPool2D()(x)
    x = Dense(n_classes, activation='softmax')(x)
  
    return x
  
  
  input = Input(input_shape)
  
  x = entry_flow(input)
  x = middle_flow(x)
  output = exit_flow(x)
  
  model = Model(input, output)
  model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy',tensorflow.keras.metrics.Precision()])
  return model
     

input_shape = 224, 224, 3
n_classes = 20

K.clear_session()
model = xception(input_shape, n_classes)
model.summary()
# Out:
# WARNING:tensorflow:From D:\ANACONDA\envs\env\Lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\env\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\env\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 112, 112, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 112, 112, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)         18432     ['re_lu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 112, 112, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 112, 112, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  separable_conv2d (Separabl  (None, 112, 112, 128)        8768      ['re_lu_1[0][0]']
#  eConv2D)
#
#  batch_normalization_2 (Bat  (None, 112, 112, 128)        512       ['separable_conv2d[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 112, 112, 128)        0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  separable_conv2d_1 (Separa  (None, 112, 112, 128)        17536     ['re_lu_2[0][0]']
#  bleConv2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)          8192      ['re_lu_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 112, 112, 128)        512       ['separable_conv2d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 56, 56, 128)          512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 128)          0         ['batch_normalization_3[0][0]'
#  D)                                                                 ]
#
#  add (Add)                   (None, 56, 56, 128)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'max_pooling2d[0][0]']
#
#  re_lu_3 (ReLU)              (None, 56, 56, 128)          0         ['add[0][0]']
#
#  separable_conv2d_2 (Separa  (None, 56, 56, 256)          33920     ['re_lu_3[0][0]']
#  bleConv2D)
#
#  batch_normalization_5 (Bat  (None, 56, 56, 256)          1024      ['separable_conv2d_2[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 56, 56, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  separable_conv2d_3 (Separa  (None, 56, 56, 256)          67840     ['re_lu_4[0][0]']
#  bleConv2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 256)          32768     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  batch_normalization_6 (Bat  (None, 56, 56, 256)          1024      ['separable_conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 28, 28, 256)          1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 256)          0         ['batch_normalization_6[0][0]'
#  g2D)                                                               ]
#
#  add_1 (Add)                 (None, 28, 28, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     , 'max_pooling2d_1[0][0]']
#
#  re_lu_5 (ReLU)              (None, 28, 28, 256)          0         ['add_1[0][0]']
#
#  separable_conv2d_4 (Separa  (None, 28, 28, 728)          188672    ['re_lu_5[0][0]']
#  bleConv2D)
#
#  batch_normalization_8 (Bat  (None, 28, 28, 728)          2912      ['separable_conv2d_4[0][0]']
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 28, 28, 728)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  separable_conv2d_5 (Separa  (None, 28, 28, 728)          536536    ['re_lu_6[0][0]']
#  bleConv2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 728)          186368    ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization_9 (Bat  (None, 28, 28, 728)          2912      ['separable_conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 14, 14, 728)          2912      ['conv2d_4[0][0]']
#  tchNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 728)          0         ['batch_normalization_9[0][0]'
#  g2D)                                                               ]
#
#  add_2 (Add)                 (None, 14, 14, 728)          0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'max_pooling2d_2[0][0]']
#
#  re_lu_7 (ReLU)              (None, 14, 14, 728)          0         ['add_2[0][0]']
#
#  separable_conv2d_6 (Separa  (None, 14, 14, 728)          536536    ['re_lu_7[0][0]']
#  bleConv2D)
#
#  batch_normalization_11 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_6[0][0]']
#  tchNormalization)
#
#  re_lu_8 (ReLU)              (None, 14, 14, 728)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  separable_conv2d_7 (Separa  (None, 14, 14, 728)          536536    ['re_lu_8[0][0]']
#  bleConv2D)
#
#  batch_normalization_12 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_7[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 14, 14, 728)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  separable_conv2d_8 (Separa  (None, 14, 14, 728)          536536    ['re_lu_9[0][0]']
#  bleConv2D)
#
#  batch_normalization_13 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_8[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 14, 14, 728)          0         ['add_2[0][0]',
#                                                                      'batch_normalization_13[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 14, 14, 728)          0         ['add_3[0][0]']
#
#  separable_conv2d_9 (Separa  (None, 14, 14, 728)          536536    ['re_lu_10[0][0]']
#  bleConv2D)
#
#  batch_normalization_14 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_9[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  separable_conv2d_10 (Separ  (None, 14, 14, 728)          536536    ['re_lu_11[0][0]']
#  ableConv2D)
#
#  batch_normalization_15 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_10[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  separable_conv2d_11 (Separ  (None, 14, 14, 728)          536536    ['re_lu_12[0][0]']
#  ableConv2D)
#
#  batch_normalization_16 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_11[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 14, 14, 728)          0         ['add_3[0][0]',
#                                                                      'batch_normalization_16[0][0]
#                                                                     ']
#
#  re_lu_13 (ReLU)             (None, 14, 14, 728)          0         ['add_4[0][0]']
#
#  separable_conv2d_12 (Separ  (None, 14, 14, 728)          536536    ['re_lu_13[0][0]']
#  ableConv2D)
#
#  batch_normalization_17 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_12[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  separable_conv2d_13 (Separ  (None, 14, 14, 728)          536536    ['re_lu_14[0][0]']
#  ableConv2D)
#
#  batch_normalization_18 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_13[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  separable_conv2d_14 (Separ  (None, 14, 14, 728)          536536    ['re_lu_15[0][0]']
#  ableConv2D)
#
#  batch_normalization_19 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_14[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 14, 14, 728)          0         ['add_4[0][0]',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ']
#
#  re_lu_16 (ReLU)             (None, 14, 14, 728)          0         ['add_5[0][0]']
#
#  separable_conv2d_15 (Separ  (None, 14, 14, 728)          536536    ['re_lu_16[0][0]']
#  ableConv2D)
#
#  batch_normalization_20 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_15[0][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  separable_conv2d_16 (Separ  (None, 14, 14, 728)          536536    ['re_lu_17[0][0]']
#  ableConv2D)
#
#  batch_normalization_21 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  separable_conv2d_17 (Separ  (None, 14, 14, 728)          536536    ['re_lu_18[0][0]']
#  ableConv2D)
#
#  batch_normalization_22 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_17[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 14, 14, 728)          0         ['add_5[0][0]',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  re_lu_19 (ReLU)             (None, 14, 14, 728)          0         ['add_6[0][0]']
#
#  separable_conv2d_18 (Separ  (None, 14, 14, 728)          536536    ['re_lu_19[0][0]']
#  ableConv2D)
#
#  batch_normalization_23 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_18[0][0]']
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  separable_conv2d_19 (Separ  (None, 14, 14, 728)          536536    ['re_lu_20[0][0]']
#  ableConv2D)
#
#  batch_normalization_24 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_19[0][0]']
#  tchNormalization)
#
#  re_lu_21 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  separable_conv2d_20 (Separ  (None, 14, 14, 728)          536536    ['re_lu_21[0][0]']
#  ableConv2D)
#
#  batch_normalization_25 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_20[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 14, 14, 728)          0         ['add_6[0][0]',
#                                                                      'batch_normalization_25[0][0]
#                                                                     ']
#
#  re_lu_22 (ReLU)             (None, 14, 14, 728)          0         ['add_7[0][0]']
#
#  separable_conv2d_21 (Separ  (None, 14, 14, 728)          536536    ['re_lu_22[0][0]']
#  ableConv2D)
#
#  batch_normalization_26 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_21[0][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  separable_conv2d_22 (Separ  (None, 14, 14, 728)          536536    ['re_lu_23[0][0]']
#  ableConv2D)
#
#  batch_normalization_27 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_22[0][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  separable_conv2d_23 (Separ  (None, 14, 14, 728)          536536    ['re_lu_24[0][0]']
#  ableConv2D)
#
#  batch_normalization_28 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_23[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 14, 14, 728)          0         ['add_7[0][0]',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  re_lu_25 (ReLU)             (None, 14, 14, 728)          0         ['add_8[0][0]']
#
#  separable_conv2d_24 (Separ  (None, 14, 14, 728)          536536    ['re_lu_25[0][0]']
#  ableConv2D)
#
#  batch_normalization_29 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_24[0][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  separable_conv2d_25 (Separ  (None, 14, 14, 728)          536536    ['re_lu_26[0][0]']
#  ableConv2D)
#
#  batch_normalization_30 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_25[0][0]']
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  separable_conv2d_26 (Separ  (None, 14, 14, 728)          536536    ['re_lu_27[0][0]']
#  ableConv2D)
#
#  batch_normalization_31 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_26[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 14, 14, 728)          0         ['add_8[0][0]',
#                                                                      'batch_normalization_31[0][0]
#                                                                     ']
#
#  re_lu_28 (ReLU)             (None, 14, 14, 728)          0         ['add_9[0][0]']
#
#  separable_conv2d_27 (Separ  (None, 14, 14, 728)          536536    ['re_lu_28[0][0]']
#  ableConv2D)
#
#  batch_normalization_32 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_27[0][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  separable_conv2d_28 (Separ  (None, 14, 14, 728)          536536    ['re_lu_29[0][0]']
#  ableConv2D)
#
#  batch_normalization_33 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_28[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  separable_conv2d_29 (Separ  (None, 14, 14, 728)          536536    ['re_lu_30[0][0]']
#  ableConv2D)
#
#  batch_normalization_34 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_29[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 14, 14, 728)          0         ['add_9[0][0]',
#                                                                      'batch_normalization_34[0][0]
#                                                                     ']
#
#  re_lu_31 (ReLU)             (None, 14, 14, 728)          0         ['add_10[0][0]']
#
#  separable_conv2d_30 (Separ  (None, 14, 14, 728)          536536    ['re_lu_31[0][0]']
#  ableConv2D)
#
#  batch_normalization_35 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_30[0][0]']
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  separable_conv2d_31 (Separ  (None, 14, 14, 1024)         752024    ['re_lu_32[0][0]']
#  ableConv2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 1024)           745472    ['add_10[0][0]']
#
#  batch_normalization_36 (Ba  (None, 14, 14, 1024)         4096      ['separable_conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_5[0][0]']
#  tchNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 7, 1024)           0         ['batch_normalization_36[0][0]
#  g2D)                                                               ']
#
#  add_11 (Add)                (None, 7, 7, 1024)           0         ['batch_normalization_37[0][0]
#                                                                     ',
#                                                                      'max_pooling2d_3[0][0]']
#
#  separable_conv2d_32 (Separ  (None, 7, 7, 1536)           1582080   ['add_11[0][0]']
#  ableConv2D)
#
#  batch_normalization_38 (Ba  (None, 7, 7, 1536)           6144      ['separable_conv2d_32[0][0]']
#  tchNormalization)
#
#  re_lu_33 (ReLU)             (None, 7, 7, 1536)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  separable_conv2d_33 (Separ  (None, 7, 7, 2048)           3159552   ['re_lu_33[0][0]']
#  ableConv2D)
#
#  batch_normalization_39 (Ba  (None, 7, 7, 2048)           8192      ['separable_conv2d_33[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 7, 7, 2048)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['re_lu_34[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 20)                   40980     ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 20902460 (79.74 MB)
# Trainable params: 20847932 (79.53 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
model_path = "XCEPTION.h5"

from keras.callbacks import ModelCheckpoint

M = ModelCheckpoint(model_path, monitor='accuracy', verbose=1, save_best_only=True)

# %%
epochs = 50
batch_size = 512

# %%
#### Fitting the model
history = model.fit(
           train_data, steps_per_epoch=train_data.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_data,validation_steps=test_data.samples // batch_size,
           callbacks=[M])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From D:\ANACONDA\envs\env\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\env\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - ETA: 0s - loss: 2.8942 - accuracy: 0.2266 - precision: 0.3600
# Epoch 1: accuracy improved from -inf to 0.22656, saving model to XCEPTION.h5
# 4/4 [==============================] - 134s 33s/step - loss: 2.8942 - accuracy: 0.2266 - precision: 0.3600 - val_loss: 2.9881 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 2/50
# 4/4 [==============================] - ETA: 0s - loss: 2.6044 - accuracy: 0.2734 - precision: 0.3750
# Epoch 2: accuracy improved from 0.22656 to 0.27344, saving model to XCEPTION.h5
# 4/4 [==============================] - 141s 17s/step - loss: 2.6044 - accuracy: 0.2734 - precision: 0.3750 - val_loss: 2.9911 - val_accuracy: 0.1016 - val_precision: 0.0000e+00
# Epoch 3/50
# 4/4 [==============================] - ETA: 0s - loss: 1.9239 - accuracy: 0.4219 - precision: 0.5593
# Epoch 3: accuracy improved from 0.27344 to 0.42188, saving model to XCEPTION.h5
# 4/4 [==============================] - 59s 14s/step - loss: 1.9239 - accuracy: 0.4219 - precision: 0.5593 - val_loss: 2.9923 - val_accuracy: 0.1172 - val_precision: 0.0000e+00
# Epoch 4/50
# 4/4 [==============================] - ETA: 0s - loss: 1.9202 - accuracy: 0.4062 - precision: 0.5075
# Epoch 4: accuracy did not improve from 0.42188
# 4/4 [==============================] - 45s 11s/step - loss: 1.9202 - accuracy: 0.4062 - precision: 0.5075 - val_loss: 2.9911 - val_accuracy: 0.1328 - val_precision: 0.0000e+00
# Epoch 5/50
# 4/4 [==============================] - ETA: 0s - loss: 2.1259 - accuracy: 0.3984 - precision: 0.4412
# Epoch 5: accuracy did not improve from 0.42188
# 4/4 [==============================] - 43s 11s/step - loss: 2.1259 - accuracy: 0.3984 - precision: 0.4412 - val_loss: 2.9930 - val_accuracy: 0.1094 - val_precision: 0.0000e+00
# Epoch 6/50
# 4/4 [==============================] - ETA: 0s - loss: 1.8280 - accuracy: 0.3906 - precision: 0.5224
# Epoch 6: accuracy did not improve from 0.42188
# 4/4 [==============================] - 44s 11s/step - loss: 1.8280 - accuracy: 0.3906 - precision: 0.5224 - val_loss: 2.9944 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 7/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7145 - accuracy: 0.3906 - precision: 0.5435
# Epoch 7: accuracy did not improve from 0.42188
# 4/4 [==============================] - 44s 11s/step - loss: 1.7145 - accuracy: 0.3906 - precision: 0.5435 - val_loss: 2.9907 - val_accuracy: 0.1016 - val_precision: 0.0000e+00
# Epoch 8/50
# 4/4 [==============================] - ETA: 0s - loss: 1.9575 - accuracy: 0.3594 - precision: 0.3684
# Epoch 8: accuracy did not improve from 0.42188
# 4/4 [==============================] - 42s 11s/step - loss: 1.9575 - accuracy: 0.3594 - precision: 0.3684 - val_loss: 2.9954 - val_accuracy: 0.0469 - val_precision: 0.0000e+00
# Epoch 9/50
# 4/4 [==============================] - ETA: 0s - loss: 1.6276 - accuracy: 0.4297 - precision: 0.5441
# Epoch 9: accuracy improved from 0.42188 to 0.42969, saving model to XCEPTION.h5
# 4/4 [==============================] - 46s 12s/step - loss: 1.6276 - accuracy: 0.4297 - precision: 0.5441 - val_loss: 2.9927 - val_accuracy: 0.0781 - val_precision: 0.0000e+00
# Epoch 10/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7757 - accuracy: 0.4062 - precision: 0.4590
# Epoch 10: accuracy did not improve from 0.42969
# 4/4 [==============================] - 42s 11s/step - loss: 1.7757 - accuracy: 0.4062 - precision: 0.4590 - val_loss: 2.9932 - val_accuracy: 0.0234 - val_precision: 0.0000e+00
# Epoch 11/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7568 - accuracy: 0.4375 - precision: 0.5574
# Epoch 11: accuracy improved from 0.42969 to 0.43750, saving model to XCEPTION.h5
# 4/4 [==============================] - 54s 15s/step - loss: 1.7568 - accuracy: 0.4375 - precision: 0.5574 - val_loss: 2.9942 - val_accuracy: 0.0234 - val_precision: 0.0000e+00
# Epoch 12/50
# 4/4 [==============================] - ETA: 0s - loss: 1.9913 - accuracy: 0.3594 - precision: 0.4098
# Epoch 12: accuracy did not improve from 0.43750
# 4/4 [==============================] - 42s 11s/step - loss: 1.9913 - accuracy: 0.3594 - precision: 0.4098 - val_loss: 2.9901 - val_accuracy: 0.1250 - val_precision: 0.0000e+00
# Epoch 13/50
# 4/4 [==============================] - ETA: 0s - loss: 1.5166 - accuracy: 0.4609 - precision: 0.6034
# Epoch 13: accuracy improved from 0.43750 to 0.46094, saving model to XCEPTION.h5
# 4/4 [==============================] - 49s 13s/step - loss: 1.5166 - accuracy: 0.4609 - precision: 0.6034 - val_loss: 2.9926 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 14/50
# 4/4 [==============================] - ETA: 0s - loss: 1.6715 - accuracy: 0.4922 - precision: 0.6364
# Epoch 14: accuracy improved from 0.46094 to 0.49219, saving model to XCEPTION.h5
# 4/4 [==============================] - 46s 12s/step - loss: 1.6715 - accuracy: 0.4922 - precision: 0.6364 - val_loss: 2.9917 - val_accuracy: 0.0547 - val_precision: 0.0000e+00
# Epoch 15/50
# 4/4 [==============================] - ETA: 0s - loss: 1.5966 - accuracy: 0.4906 - precision: 0.5574
# Epoch 15: accuracy did not improve from 0.49219
# 4/4 [==============================] - 36s 9s/step - loss: 1.5966 - accuracy: 0.4906 - precision: 0.5574 - val_loss: 2.9975 - val_accuracy: 0.0391 - val_precision: 0.0000e+00
# Epoch 16/50
# 4/4 [==============================] - ETA: 0s - loss: 1.3738 - accuracy: 0.4609 - precision: 0.5781
# Epoch 16: accuracy did not improve from 0.49219
# 4/4 [==============================] - 43s 11s/step - loss: 1.3738 - accuracy: 0.4609 - precision: 0.5781 - val_loss: 2.9945 - val_accuracy: 0.0312 - val_precision: 0.0000e+00
# Epoch 17/50
# 4/4 [==============================] - ETA: 0s - loss: 1.5488 - accuracy: 0.4453 - precision: 0.5867
# Epoch 17: accuracy did not improve from 0.49219
# 4/4 [==============================] - 42s 11s/step - loss: 1.5488 - accuracy: 0.4453 - precision: 0.5867 - val_loss: 2.9904 - val_accuracy: 0.0469 - val_precision: 0.0000e+00
# Epoch 18/50
# 4/4 [==============================] - ETA: 0s - loss: 1.6279 - accuracy: 0.4531 - precision: 0.5797
# Epoch 18: accuracy did not improve from 0.49219
# 4/4 [==============================] - 42s 11s/step - loss: 1.6279 - accuracy: 0.4531 - precision: 0.5797 - val_loss: 2.9929 - val_accuracy: 0.0469 - val_precision: 0.0000e+00
# Epoch 19/50
# 4/4 [==============================] - ETA: 0s - loss: 1.6648 - accuracy: 0.4062 - precision: 0.5517
# Epoch 19: accuracy did not improve from 0.49219
# 4/4 [==============================] - 42s 11s/step - loss: 1.6648 - accuracy: 0.4062 - precision: 0.5517 - val_loss: 2.9913 - val_accuracy: 0.0391 - val_precision: 0.0000e+00
# Epoch 20/50
# 4/4 [==============================] - ETA: 0s - loss: 1.5508 - accuracy: 0.4844 - precision: 0.5522
# Epoch 20: accuracy did not improve from 0.49219
# 4/4 [==============================] - 42s 11s/step - loss: 1.5508 - accuracy: 0.4844 - precision: 0.5522 - val_loss: 2.9912 - val_accuracy: 0.0391 - val_precision: 0.0000e+00
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 1.8142 - accuracy: 0.3679 - precision: 0.5682
# Epoch 21: accuracy did not improve from 0.49219
# 4/4 [==============================] - 36s 9s/step - loss: 1.8142 - accuracy: 0.3679 - precision: 0.5682 - val_loss: 2.9923 - val_accuracy: 0.0469 - val_precision: 0.0000e+00
# Epoch 22/50
# 4/4 [==============================] - ETA: 0s - loss: 1.6674 - accuracy: 0.4375 - precision: 0.5968
# Epoch 22: accuracy did not improve from 0.49219
# 4/4 [==============================] - 42s 11s/step - loss: 1.6674 - accuracy: 0.4375 - precision: 0.5968 - val_loss: 2.9953 - val_accuracy: 0.0312 - val_precision: 0.0000e+00
# Epoch 23/50
# 4/4 [==============================] - ETA: 0s - loss: 1.5839 - accuracy: 0.5000 - precision: 0.6800
# Epoch 23: accuracy improved from 0.49219 to 0.50000, saving model to XCEPTION.h5
# 4/4 [==============================] - 49s 13s/step - loss: 1.5839 - accuracy: 0.5000 - precision: 0.6800 - val_loss: 2.9920 - val_accuracy: 0.0234 - val_precision: 0.0000e+00
# Epoch 24/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2097 - accuracy: 0.5938 - precision: 0.7414
# Epoch 24: accuracy improved from 0.50000 to 0.59375, saving model to XCEPTION.h5
# 4/4 [==============================] - 48s 13s/step - loss: 1.2097 - accuracy: 0.5938 - precision: 0.7414 - val_loss: 2.9937 - val_accuracy: 0.0156 - val_precision: 0.0000e+00
# Epoch 25/50
# 4/4 [==============================] - ETA: 0s - loss: 1.4273 - accuracy: 0.5000 - precision: 0.6711
# Epoch 25: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.4273 - accuracy: 0.5000 - precision: 0.6711 - val_loss: 2.9966 - val_accuracy: 0.0547 - val_precision: 0.0000e+00
# Epoch 26/50
# 4/4 [==============================] - ETA: 0s - loss: 1.1873 - accuracy: 0.5234 - precision: 0.7162
# Epoch 26: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.1873 - accuracy: 0.5234 - precision: 0.7162 - val_loss: 2.9915 - val_accuracy: 0.0312 - val_precision: 0.0000e+00
# Epoch 27/50
# 4/4 [==============================] - ETA: 0s - loss: 1.4064 - accuracy: 0.5547 - precision: 0.6087
# Epoch 27: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.4064 - accuracy: 0.5547 - precision: 0.6087 - val_loss: 2.9926 - val_accuracy: 0.0234 - val_precision: 0.0000e+00
# Epoch 28/50
# 4/4 [==============================] - ETA: 0s - loss: 1.6994 - accuracy: 0.4688 - precision: 0.5541
# Epoch 28: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.6994 - accuracy: 0.4688 - precision: 0.5541 - val_loss: 2.9788 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 29/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7700 - accuracy: 0.4609 - precision: 0.5190
# Epoch 29: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.7700 - accuracy: 0.4609 - precision: 0.5190 - val_loss: 2.9830 - val_accuracy: 0.0469 - val_precision: 0.0000e+00
# Epoch 30/50
# 4/4 [==============================] - ETA: 0s - loss: 1.4151 - accuracy: 0.4844 - precision: 0.6441
# Epoch 30: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.4151 - accuracy: 0.4844 - precision: 0.6441 - val_loss: 2.9815 - val_accuracy: 0.0469 - val_precision: 0.0000e+00
# Epoch 31/50
# 4/4 [==============================] - ETA: 0s - loss: 1.4393 - accuracy: 0.5000 - precision: 0.7018
# Epoch 31: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.4393 - accuracy: 0.5000 - precision: 0.7018 - val_loss: 2.9937 - val_accuracy: 0.0078 - val_precision: 0.0000e+00
# Epoch 32/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2281 - accuracy: 0.5547 - precision: 0.6951
# Epoch 32: accuracy did not improve from 0.59375
# 4/4 [==============================] - 41s 11s/step - loss: 1.2281 - accuracy: 0.5547 - precision: 0.6951 - val_loss: 2.9856 - val_accuracy: 0.0391 - val_precision: 0.0000e+00
# Epoch 33/50
# 4/4 [==============================] - ETA: 0s - loss: 1.1977 - accuracy: 0.5703 - precision: 0.7324
# Epoch 33: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.1977 - accuracy: 0.5703 - precision: 0.7324 - val_loss: 2.9919 - val_accuracy: 0.0312 - val_precision: 0.0000e+00
# Epoch 34/50
# 4/4 [==============================] - ETA: 0s - loss: 1.1975 - accuracy: 0.5547 - precision: 0.6265
# Epoch 34: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.1975 - accuracy: 0.5547 - precision: 0.6265 - val_loss: 2.9826 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 35/50
# 4/4 [==============================] - ETA: 0s - loss: 1.5177 - accuracy: 0.5156 - precision: 0.5802
# Epoch 35: accuracy did not improve from 0.59375
# 4/4 [==============================] - 42s 11s/step - loss: 1.5177 - accuracy: 0.5156 - precision: 0.5802 - val_loss: 2.9871 - val_accuracy: 0.0391 - val_precision: 0.0000e+00
# Epoch 36/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0218 - accuracy: 0.6172 - precision: 0.7529
# Epoch 36: accuracy improved from 0.59375 to 0.61719, saving model to XCEPTION.h5
# 4/4 [==============================] - 56s 15s/step - loss: 1.0218 - accuracy: 0.6172 - precision: 0.7529 - val_loss: 2.9841 - val_accuracy: 0.0234 - val_precision: 0.0000e+00
# Epoch 37/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2079 - accuracy: 0.5312 - precision: 0.6190
# Epoch 37: accuracy did not improve from 0.61719
# 4/4 [==============================] - 44s 11s/step - loss: 1.2079 - accuracy: 0.5312 - precision: 0.6190 - val_loss: 2.9679 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 38/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0606 - accuracy: 0.6719 - precision: 0.8105
# Epoch 38: accuracy improved from 0.61719 to 0.67188, saving model to XCEPTION.h5
# 4/4 [==============================] - 45s 12s/step - loss: 1.0606 - accuracy: 0.6719 - precision: 0.8105 - val_loss: 2.9928 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 39/50
# 4/4 [==============================] - ETA: 0s - loss: 1.1303 - accuracy: 0.5938 - precision: 0.7531
# Epoch 39: accuracy did not improve from 0.67188
# 4/4 [==============================] - 42s 11s/step - loss: 1.1303 - accuracy: 0.5938 - precision: 0.7531 - val_loss: 2.9687 - val_accuracy: 0.0391 - val_precision: 0.0000e+00
# Epoch 40/50
# 4/4 [==============================] - ETA: 0s - loss: 1.3913 - accuracy: 0.4844 - precision: 0.6203
# Epoch 40: accuracy did not improve from 0.67188
# 4/4 [==============================] - 41s 11s/step - loss: 1.3913 - accuracy: 0.4844 - precision: 0.6203 - val_loss: 2.9913 - val_accuracy: 0.0469 - val_precision: 0.0000e+00
# Epoch 41/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2216 - accuracy: 0.5859 - precision: 0.6484
# Epoch 41: accuracy did not improve from 0.67188
# 4/4 [==============================] - 42s 11s/step - loss: 1.2216 - accuracy: 0.5859 - precision: 0.6484 - val_loss: 2.9813 - val_accuracy: 0.0312 - val_precision: 0.0000e+00
# Epoch 42/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2336 - accuracy: 0.5703 - precision: 0.6905
# Epoch 42: accuracy did not improve from 0.67188
# 4/4 [==============================] - 42s 11s/step - loss: 1.2336 - accuracy: 0.5703 - precision: 0.6905 - val_loss: 2.9649 - val_accuracy: 0.0469 - val_precision: 0.0000e+00
# Epoch 43/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2789 - accuracy: 0.5938 - precision: 0.7294
# Epoch 43: accuracy did not improve from 0.67188
# 4/4 [==============================] - 42s 11s/step - loss: 1.2789 - accuracy: 0.5938 - precision: 0.7294 - val_loss: 2.9809 - val_accuracy: 0.0469 - val_precision: 0.0000e+00
# Epoch 44/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9740 - accuracy: 0.7075 - precision: 0.8205
# Epoch 44: accuracy improved from 0.67188 to 0.70755, saving model to XCEPTION.h5
# 4/4 [==============================] - 43s 13s/step - loss: 0.9740 - accuracy: 0.7075 - precision: 0.8205 - val_loss: 2.9715 - val_accuracy: 0.0234 - val_precision: 0.0000e+00
# Epoch 45/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2320 - accuracy: 0.6172 - precision: 0.7000
# Epoch 45: accuracy did not improve from 0.70755
# 4/4 [==============================] - 43s 11s/step - loss: 1.2320 - accuracy: 0.6172 - precision: 0.7000 - val_loss: 2.9793 - val_accuracy: 0.0156 - val_precision: 0.0000e+00
# Epoch 46/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9121 - accuracy: 0.7188 - precision: 0.8202
# Epoch 46: accuracy improved from 0.70755 to 0.71875, saving model to XCEPTION.h5
# 4/4 [==============================] - 46s 12s/step - loss: 0.9121 - accuracy: 0.7188 - precision: 0.8202 - val_loss: 2.9582 - val_accuracy: 0.0547 - val_precision: 0.0000e+00
# Epoch 47/50
# 4/4 [==============================] - ETA: 0s - loss: 1.2677 - accuracy: 0.5703 - precision: 0.6706
# Epoch 47: accuracy did not improve from 0.71875
# 4/4 [==============================] - 42s 11s/step - loss: 1.2677 - accuracy: 0.5703 - precision: 0.6706 - val_loss: 2.9754 - val_accuracy: 0.0078 - val_precision: 0.0000e+00
# Epoch 48/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0244 - accuracy: 0.5781 - precision: 0.6739
# Epoch 48: accuracy did not improve from 0.71875
# 4/4 [==============================] - 42s 11s/step - loss: 1.0244 - accuracy: 0.5781 - precision: 0.6739 - val_loss: 2.9607 - val_accuracy: 0.0391 - val_precision: 0.0000e+00
# Epoch 49/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9950 - accuracy: 0.6250 - precision: 0.7586
# Epoch 49: accuracy did not improve from 0.71875
# 4/4 [==============================] - 42s 11s/step - loss: 0.9950 - accuracy: 0.6250 - precision: 0.7586 - val_loss: 2.9674 - val_accuracy: 0.0781 - val_precision: 0.0000e+00
# Epoch 50/50
# 4/4 [==============================] - ETA: 0s - loss: 1.1053 - accuracy: 0.6094 - precision: 0.6875
# Epoch 50: accuracy did not improve from 0.71875
# 4/4 [==============================] - 42s 11s/step - loss: 1.1053 - accuracy: 0.6094 - precision: 0.6875 - val_loss: 2.9515 - val_accuracy: 0.0547 - val_precision: 0.0000e+00

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['accuracy'][i]*100,2),xy=(i,history.history['accuracy'][i]))

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['loss'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['loss'][i]))

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
